# %% [markdown]
# <a href="https://colab.research.google.com/github/prathameshatkare/ADYPSOE/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# User Engagement Survey for Malaysian Web Platforms
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data =pd.read_excel("UserEngagementSurvey.xlsx")
data.head()
# Out:
#                       Timestamp  \
# 0  2024/12/24 11:33:49 AM GMT+8
# 1  2024/12/24 11:33:49 AM GMT+8
# 2  2024/12/24 11:33:49 AM GMT+8
# 3  2024/12/24 11:33:49 AM GMT+8
# 4  2024/12/24 11:33:49 AM GMT+8
#
#   By clicking 'I agree' below, you are indicating that you have read and understood this consent form and agree to participate in this research study. If you are under 18 years old, you confirm that you have obtained parental or guardian consent to participate.   \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   What is your age? What is your gender? What is your occupation?  \
# 0          Under 18               Female                 Employed
# 1           25 - 34               Female            Self-employed
# 2           55 - 64               Female                  Retired
# 3           55 - 64               Female               Unemployed
# 4      65 and above                 Male               Unemployed
#
#   How often do you use the internet?  \
# 0              Several times a month
# 1                             Rarely
# 2                       Once a month
# 3                             Rarely
# 4              Several times a month
#
#   Which device do you primarily use to access the internet?  \
# 0                                             Laptop
# 1                                             Laptop
# 2                                         Smartphone
# 3                                             Tablet
# 4                                             Laptop
#
#   What is your main reason for using the internet?  \
# 0                                        Education
# 1                                             Work
# 2                                     Social Media
# 3                                     Social Media
# 4                                     Social Media
#
#   What types of Malaysian web platforms do you frequently visit?  \
# 0                                Government services
# 1                                       News portals
# 2                                Government services
# 3                                         E-commerce
# 4                                  Educational sites
#
#   How often do you interact with online shopping on websites?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  2
#
#   How often do you interact with reading articles on websites?  \
# 0                                          1 (Never)
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#   How often do you interact with watching videos on websites?  \
# 0                                          1 (Never)
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#    How often do you interact with participating in online discussions on websites?  \
# 0                                                  3
# 1                                                  4
# 2                                                  2
# 3                                                  5
# 4                                                  5
#
#   How often do you interact with social media integration on websites?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  3
# 4                                                  2
#
#    How satisfied are you with the overall user experience of Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Very Dissatisfied' and 5 is 'Very Satisfied')   \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  1
# 4                                                  4
#
#    How likely are you to recommend Malaysian web platforms to others? (Rate on a scale of 1-5, where 1 is 'Very Unlikely' and 5 is 'Very Likely')  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    How accessible do you find Malaysian web platforms for people with disabilities? (Rate on a scale of 1-5, where 1 is 'Not Accessible at All' and 5 is 'Very Accessible')  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    How successful are you at finding what you need on Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Never Successful' and 5 is 'Always Successful')  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  5
# 4                                                  2
#
#   What improvements would you suggest for Malaysian web platforms to enhance your experience?   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Are there any additional features you would like to see implemented on Malaysian web platforms?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# Data Cleaning And Preparation

# Dropping columns by index positions
columns_to_drop = [0, 1]  # Index positions of 'Timestamp' and 'Terms Condition Agree'
data = data.drop(data.columns[columns_to_drop], axis=1)

print("\nDataset after dropping columns by index positions:")
data.head()
# Out:
# Dataset after dropping columns by index positions:
#      webplatform_types  for_online_shopping  for_reading_articles  \
# 0  Government services                    4                     1
# 1         News portals                    3                     2
# 2  Government services                    4                     2
# 3           E-commerce                    3                     2
# 4    Educational sites                    2                     2
#
#    for_watching_videos  for_online_discussions  social_media_integration  \
# 0                    1                       3                         2
# 1                    3                       4                         2
# 2                    3                       2                         2
# 3                    2                       5                         3
# 4                    2                       5                         2
#
#    overall_experience  will_recommend  accessiblity_for_disable  \
# 0                   4               4                         3
# 1                   3               4                         3
# 2                   4               4                         4
# 3                   1               4                         4
# 4                   4               3                         3
#
#    rating_for_finding_needs   improvements additional_features
# 0                         2  Not Specified       Not Specified
# 1                         3  Not Specified       Not Specified
# 2                         1  Not Specified       Not Specified
# 3                         5  Not Specified       Not Specified
# 4                         2  Not Specified       Not Specified

# %%
#exploratory data analysis
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       151 non-null    object
#  1   gender                    151 non-null    object
#  2   occupation                151 non-null    object
#  3   internet_usage            151 non-null    object
#  4   device                    151 non-null    object
#  5   reason                    151 non-null    object
#  6   webplatform_types         151 non-null    object
#  7   for_online_shopping       151 non-null    int64
#  8   for_reading_articles      151 non-null    int64
#  9   for_watching_videos       151 non-null    int64
#  10  for_online_discussions    151 non-null    int64
#  11  social_media_integration  151 non-null    int64
#  12  overall_experience        151 non-null    int64
#  13  will_recommend            151 non-null    int64
#  14  accessiblity_for_disable  151 non-null    int64
#  15  rating_for_finding_needs  151 non-null    int64
#  16  improvements              151 non-null    object
#  17  additional_features       151 non-null    object
# dtypes: int64(9), object(9)
# memory usage: 21.4+ KB
# None

# %%
print(data.describe())
# Out:
#        for_online_shopping  for_reading_articles  for_watching_videos  \
# count           151.000000            151.000000           151.000000
# mean              3.013245              2.927152             3.139073
# std               1.210987              1.183776             1.143327
# min               1.000000              1.000000             1.000000
# 25%               2.000000              2.000000             2.000000
# 50%               3.000000              3.000000             3.000000
# 75%               4.000000              4.000000             4.000000
# max               5.000000              5.000000             5.000000
#
#        for_online_discussions  social_media_integration  overall_experience  \
# count              151.000000                151.000000          151.000000
# mean                 3.019868                  3.046358            3.178808
# std                  1.202609                  1.223861            1.233348
# min                  1.000000                  1.000000            1.000000
# 25%                  2.000000                  2.000000            2.000000
# 50%                  3.000000                  3.000000            3.000000
# 75%                  4.000000                  4.000000            4.000000
# max                  5.000000                  5.000000            5.000000
#
#        will_recommend  accessiblity_for_disable  rating_for_finding_needs
# count      151.000000                151.000000                151.000000
# mean         2.947020                  3.079470                  3.046358
# std          1.159242                  1.197348                  1.212918
# min          1.000000                  1.000000                  1.000000
# 25%          2.000000                  2.000000                  2.000000
# 50%          3.000000                  3.000000                  3.000000
# 75%          4.000000                  4.000000                  4.000000
# max          5.000000                  5.000000                  5.000000

# %%
data.columns
# Out:
# Index(['age', 'gender', 'occupation', 'internet_usage', 'device', 'reason',
#        'webplatform_types', 'for_online_shopping', 'for_reading_articles',
#        'for_watching_videos', 'for_online_discussions',
#        'social_media_integration', 'overall_experience', 'will_recommend',
#        'accessiblity_for_disable', 'rating_for_finding_needs', 'improvements',
#        'additional_features'],
#       dtype='object')

# %%
#Lets remove unwanted columns
col_to_drop= [0,1]
data = data.drop(data.columns[col_to_drop],axis = 1)
print('Dataset after dropping irrevelant columns:')
data
# Out:
# Dataset after dropping irrevelant columns:
#     What is your age? What is your gender? What is your occupation?  \
# 0            Under 18               Female                 Employed
# 1             25 - 34               Female            Self-employed
# 2             55 - 64               Female                  Retired
# 3             55 - 64               Female               Unemployed
# 4        65 and above                 Male               Unemployed
# ..                ...                  ...                      ...
# 146           45 - 54               Female            Self-employed
# 147           18 - 24               Female                  Student
# 148           55 - 64                 Male                 Employed
# 149           25 - 34               Female                  Student
# 150           55 - 64               Female                  Retired
#
#     How often do you use the internet?  \
# 0                Several times a month
# 1                               Rarely
# 2                         Once a month
# 3                               Rarely
# 4                Several times a month
# ..                                 ...
# 146                              Daily
# 147                        Once a week
# 148              Several times a month
# 149                       Once a month
# 150                       Once a month
#
#     Which device do you primarily use to access the internet?  \
# 0                                               Laptop
# 1                                               Laptop
# 2                                           Smartphone
# 3                                               Tablet
# 4                                               Laptop
# ..                                                 ...
# 146                                            Desktop
# 147                                            Desktop
# 148                                            Desktop
# 149                                             Tablet
# 150                                             Tablet
#
#     What is your main reason for using the internet?  \
# 0                                          Education
# 1                                               Work
# 2                                       Social Media
# 3                                       Social Media
# 4                                       Social Media
# ..                                               ...
# 146                                    Entertainment
# 147                             News and Information
# 148                                    Entertainment
# 149                                        Education
# 150                             News and Information
#
#     What types of Malaysian web platforms do you frequently visit?  \
# 0                                  Government services
# 1                                         News portals
# 2                                  Government services
# 3                                           E-commerce
# 4                                    Educational sites
# ..                                                 ...
# 146                                  Educational sites
# 147                                Government services
# 148                                         E-commerce
# 149                                       Social media
# 150                                Government services
#
#     How often do you interact with online shopping on websites?  \
# 0                                                    4
# 1                                                    3
# 2                                                    4
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 146                                                  4
# 147                                          1 (Never)
# 148                                                  2
# 149                                          1 (Never)
# 150                                                  4
#
#     How often do you interact with reading articles on websites?  \
# 0                                            1 (Never)
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 146                                          1 (Never)
# 147                                                  3
# 148                                          1 (Never)
# 149                                                  4
# 150                                                  4
#
#     How often do you interact with watching videos on websites?  \
# 0                                            1 (Never)
# 1                                                    3
# 2                                                    3
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 146                                                  2
# 147                                                  4
# 148                                                  3
# 149                                                  3
# 150                                                  5
#
#      How often do you interact with participating in online discussions on websites?  \
# 0                                                    3
# 1                                                    4
# 2                                                    2
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 146                                                  3
# 147                                                  4
# 148                                                  3
# 149                                                  3
# 150                                                  4
#
#     How often do you interact with social media integration on websites?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 146                                                  2
# 147                                                  5
# 148                                                  2
# 149                                                  4
# 150                                                  5
#
#      How satisfied are you with the overall user experience of Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Very Dissatisfied' and 5 is 'Very Satisfied')   \
# 0                                                    4
# 1                                                    3
# 2                                                    4
# 3                                                    1
# 4                                                    4
# ..                                                 ...
# 146                                                  3
# 147                                                  2
# 148                                                  3
# 149                                                  3
# 150                                                  3
#
#      How likely are you to recommend Malaysian web platforms to others? (Rate on a scale of 1-5, where 1 is 'Very Unlikely' and 5 is 'Very Likely')  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 146                                                  3
# 147                                                  3
# 148                                                  1
# 149                                                  4
# 150                                                  3
#
#      How accessible do you find Malaysian web platforms for people with disabilities? (Rate on a scale of 1-5, where 1 is 'Not Accessible at All' and 5 is 'Very Accessible')  \
# 0                                                    3
# 1                                                    3
# 2                                                    4
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 146                                                  3
# 147                                                  4
# 148                                                  3
# 149                                                  4
# 150                                                  2
#
#      How successful are you at finding what you need on Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Never Successful' and 5 is 'Always Successful')  \
# 0                                                    2
# 1                                                    3
# 2                                                    1
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 146                                                  5
# 147                                                  4
# 148                                                  5
# 149                                                  4
# 150                                                  3
#
#     What improvements would you suggest for Malaysian web platforms to enhance your experience?   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 146                               Faster Loading Times
# 147                                Local Customization
# 148                               Faster Loading Times
# 149                        Better Search Functionality
# 150                           Enhanced Data Protection
#
#     Are there any additional features you would like to see implemented on Malaysian web platforms?
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 146                            Sustainability Features
# 147                            Sustainability Features
# 148                 AI and Data-Driven Personalization
# 149                 AI and Data-Driven Personalization
# 150                        Public Service Enhancements
#
# [151 rows x 18 columns]

# %%
# 1. Examine the shape of the data
print("Shape of the DataFrame:", data.shape)

# 2. Inspect data types
print("\nData Types of Columns:")
print(data.dtypes)

# 3. Calculate descriptive statistics
print("\nDescriptive Statistics for Numerical Columns:")
print(data.describe())

# 4. Identify missing values
print("\nMissing Values in Each Column:")
print(data.isnull().sum())

# 6. Analyze the unique values of categorical columns
for column in data.columns:
  if data[column].dtype == 'object':
    print(f"\nUnique values in column '{column}':")
    print(data[column].value_counts())
# Out:
# Shape of the DataFrame: (151, 18)
#
# Data Types of Columns:
# age                         object
# gender                      object
# occupation                  object
# internet_usage              object
# device                      object
# reason                      object
# webplatform_types           object
# for_online_shopping         object
# for_reading_articles        object
# for_watching_videos         object
# for_online_discussions       int64
# social_media_integration    object
# overall_experience           int64
# will_recommend               int64
# accessiblity_for_disable     int64
# rating_for_finding_needs     int64
# improvements                object
# additional_features         object
# dtype: object
#
# Descriptive Statistics for Numerical Columns:
#        for_online_discussions  overall_experience  will_recommend  \
# count              151.000000          151.000000      151.000000
# mean                 3.019868            3.178808        2.947020
# std                  1.202609            1.233348        1.159242
# min                  1.000000            1.000000        1.000000
# 25%                  2.000000            2.000000        2.000000
# 50%                  3.000000            3.000000        3.000000
# 75%                  4.000000            4.000000        4.000000
# max                  5.000000            5.000000        5.000000
#
#        accessiblity_for_disable  rating_for_finding_needs
# count                151.000000                151.000000
# mean                   3.079470                  3.046358
# std                    1.197348                  1.212918
# min                    1.000000                  1.000000
# 25%                    2.000000                  2.000000
# 50%                    3.000000                  3.000000
# 75%                    4.000000                  4.000000
# max                    5.000000                  5.000000
#
# Missing Values in Each Column:
# age                          0
# gender                       0
# occupation                   0
# internet_usage               0
# device                       0
# reason                       0
# webplatform_types            0
# for_online_shopping          0
# for_reading_articles         0
# for_watching_videos          0
# for_online_discussions       0
# social_media_integration     0
# overall_experience           0
# will_recommend               0
# accessiblity_for_disable     0
# rating_for_finding_needs     0
# improvements                39
# additional_features         39
# dtype: int64
#
# Unique values in column 'age':
# age
# 25-34     31
# 45-54     27
# 55-64     26
# 18-24     20
# 0-18      18
# 35-44     18
# 65-100    11
# Name: count, dtype: int64
#
# Unique values in column 'gender':
# gender
# Female    84
# Male      67
# Name: count, dtype: int64
#
# Unique values in column 'occupation':
# occupation
# Unemployed       43
# Self-employed    33
# Employed         31
# Retired          25
# Student          19
# Name: count, dtype: int64
#
# Unique values in column 'internet_usage':
# internet_usage
# Several times a month    37
# Once a month             35
# Once a week              29
# Several times a week     19
# Rarely                   17
# Daily                    14
# Name: count, dtype: int64
#
# Unique values in column 'device':
# device
# Laptop        61
# Tablet        43
# Desktop       27
# Smartphone    20
# Name: count, dtype: int64
#
# Unique values in column 'reason':
# reason
# Entertainment           39
# Social Media            33
# Education               27
# News and Information    20
# Work                    17
# Shopping                15
# Name: count, dtype: int64
#
# Unique values in column 'webplatform_types':
# webplatform_types
# Blogs                  30
# News portals           27
# Social media           25
# Educational sites      24
# Government services    21
# E-commerce             12
# Forums                 12
# Name: count, dtype: int64
#
# Unique values in column 'for_online_shopping':
# for_online_shopping
# 4             42
# 2             38
# 3             36
# 1 (Never)     18
# 5 (Always)    17
# Name: count, dtype: int64
#
# Unique values in column 'for_reading_articles':
# for_reading_articles
# 3             42
# 4             38
# 2             37
# 1 (Never)     20
# 5 (Always)    14
# Name: count, dtype: int64
#
# Unique values in column 'for_watching_videos':
# for_watching_videos
# 3            45
# 4            45
# 2            30
# 5            17
# 1 (Never)    14
# Name: count, dtype: int64
#
# Unique values in column 'social_media_integration':
# social_media_integration
# 4            42
# 2            39
# 3            34
# 5            19
# 1 (Never)    17
# Name: count, dtype: int64
#
# Unique values in column 'improvements':
# improvements
# Mobile Optimization            23
# Faster Loading Times           23
# Better Search Functionality    19
# Local Customization            13
# Enhanced Data Protection       13
# Modern and Clean Design        13
# Secure Transactions             8
# Name: count, dtype: int64
#
# Unique values in column 'additional_features':
# additional_features
# AI and Data-Driven Personalization    25
# Sustainability Features               24
# Community and Engagement Tools        19
# Unified Payment Gateways              18
# Public Service Enhancements           16
# Advanced Localization Features        10
# Name: count, dtype: int64

# %%
# Data Cleaning And Preparation

# Dropping columns by index positions
columns_to_drop = [0, 1]  # Index positions of 'Timestamp' and 'Terms Condition Agree'
data = data.drop(data.columns[columns_to_drop], axis=1)

print("\nDataset after dropping columns by index positions:")
data.head()
# Out:
# Dataset after dropping columns by index positions:
#       occupation         internet_usage      device        reason  \
# 0       Employed  Several times a month      Laptop     Education
# 1  Self-employed                 Rarely      Laptop          Work
# 2        Retired           Once a month  Smartphone  Social Media
# 3     Unemployed                 Rarely      Tablet  Social Media
# 4     Unemployed  Several times a month      Laptop  Social Media
#
#      webplatform_types  for_online_shopping  for_reading_articles  \
# 0  Government services                    4                     1
# 1         News portals                    3                     2
# 2  Government services                    4                     2
# 3           E-commerce                    3                     2
# 4    Educational sites                    2                     2
#
#    for_watching_videos  for_online_discussions  social_media_integration  \
# 0                    1                       3                         2
# 1                    3                       4                         2
# 2                    3                       2                         2
# 3                    2                       5                         3
# 4                    2                       5                         2
#
#    overall_experience  will_recommend  accessiblity_for_disable  \
# 0                   4               4                         3
# 1                   3               4                         3
# 2                   4               4                         4
# 3                   1               4                         4
# 4                   4               3                         3
#
#    rating_for_finding_needs   improvements additional_features
# 0                         2  Not Specified       Not Specified
# 1                         3  Not Specified       Not Specified
# 2                         1  Not Specified       Not Specified
# 3                         5  Not Specified       Not Specified
# 4                         2  Not Specified       Not Specified

# %%
import matplotlib.pyplot as plt

# 5. Explore potential outliers using boxplots only
for column in data.columns:
    if pd.api.types.is_numeric_dtype(data[column]):
        plt.figure(figsize=(8, 4))
        plt.boxplot(data[column])
        plt.title(f"Boxplot of {column}")
        plt.ylabel(column)
        plt.show()

# %%
#Lets rename the Columns to simply and for better understanding
data.columns
# Out:
# Index(['What is your occupation?', 'How often do you use the internet?',
#        'Which device do you primarily use to access the internet?',
#        'What is your main reason for using the internet?',
#        'What types of Malaysian web platforms do you frequently visit?',
#        'How often do you interact with online shopping on websites?',
#        'How often do you interact with reading articles on websites?',
#        'How often do you interact with watching videos on websites?',
#        'How often do you interact with participating in online discussions on websites?',
#        'How often do you interact with social media integration on websites?',
#        'How satisfied are you with the overall user experience of Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Very Dissatisfied' and 5 is 'Very Satisfied') ',
#        'How likely are you to recommend Malaysian web platforms to others? (Rate on a scale of 1-5, where 1 is 'Very Unlikely' and 5 is 'Very Likely')',
#        'How accessible do you find Malaysian web platforms for people with disabilities? (Rate on a scale of 1-5, where 1 is 'Not Accessible at All' and 5 is 'Very Accessible')',
#        'How successful are you at finding what you need on Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Never Successful' and 5 is 'Always Successful')',
#        'What improvements would you suggest for Malaysian web platforms to enhance your experience? ',
#        'Are there any additional features you would like to see implemented on Malaysian web platforms?'],
#       dtype='object')

# %%
# Data Cleaning And Preparation

# Dropping columns by index positions
columns_to_drop = [0, 1]  # Index positions of 'Timestamp' and 'Terms Condition Agree'
data = data.drop(data.columns[columns_to_drop], axis=1)

print("\nDataset after dropping columns by index positions:")
data.head()
# Out:
# Dataset after dropping columns by index positions:
#        device        reason    webplatform_types  for_online_shopping  \
# 0      Laptop     Education  Government services                    4
# 1      Laptop          Work         News portals                    3
# 2  Smartphone  Social Media  Government services                    4
# 3      Tablet  Social Media           E-commerce                    3
# 4      Laptop  Social Media    Educational sites                    2
#
#    for_reading_articles  for_watching_videos  for_online_discussions  \
# 0                     1                    1                       3
# 1                     2                    3                       4
# 2                     2                    3                       2
# 3                     2                    2                       5
# 4                     2                    2                       5
#
#    social_media_integration  overall_experience  will_recommend  \
# 0                         2                   4               4
# 1                         2                   3               4
# 2                         2                   4               4
# 3                         3                   1               4
# 4                         2                   4               3
#
#    accessiblity_for_disable  rating_for_finding_needs   improvements  \
# 0                         3                         2  Not Specified
# 1                         3                         3  Not Specified
# 2                         4                         1  Not Specified
# 3                         4                         5  Not Specified
# 4                         3                         2  Not Specified
#
#   additional_features
# 0       Not Specified
# 1       Not Specified
# 2       Not Specified
# 3       Not Specified
# 4       Not Specified

# %%
# Renaming columns
data.rename(columns={
    'What is your age?': 'age',
    'What is your gender?': 'gender',
    'What is your occupation?': 'occupation',
    'How often do you use the internet?':'internet_usage',
    'Which device do you primarily use to access the internet?':'device',
    'What is your main reason for using the internet?':'reason',
    'What types of Malaysian web platforms do you frequently visit?':'webplatform_types',
    'How often do you interact with online shopping on websites?':'for_online_shopping',
    'How often do you interact with reading articles on websites?':'for_reading_articles',
    'How often do you interact with watching videos on websites?':'for_watching_videos',
    'How often do you interact with participating in online discussions on websites?':'for_online_discussions',
    'How often do you interact with social media integration on websites?':'social_media_integration',
    "How satisfied are you with the overall user experience of Malaysian web platforms? (Rate on a scale of 1-5, where 1 is 'Very Dissatisfied' and 5 is 'Very Satisfied') ":'overall_experience',
    'How likely are you to recommend Malaysian web platforms to others? (Rate on a scale of 1-5, where 1 is \'Very Unlikely\' and 5 is \'Very Likely\')':'will_recommend',
    'How accessible do you find Malaysian web platforms for people with disabilities? (Rate on a scale of 1-5, where 1 is \'Not Accessible at All\' and 5 is \'Very Accessible\')':'accessiblity_for_disable',
    'How successful are you at finding what you need on Malaysian web platforms? (Rate on a scale of 1-5, where 1 is \'Never Successful\' and 5 is \'Always Successful\')':'rating_for_finding_needs',
    "What improvements would you suggest for Malaysian web platforms to enhance your experience? ":'improvements',
    'Are there any additional features you would like to see implemented on Malaysian web platforms?':'additional_features'
}, inplace=True)

data.head()
# Out:
#             age  gender     occupation         internet_usage      device  \
# 0      Under 18  Female       Employed  Several times a month      Laptop
# 1       25 - 34  Female  Self-employed                 Rarely      Laptop
# 2       55 - 64  Female        Retired           Once a month  Smartphone
# 3       55 - 64  Female     Unemployed                 Rarely      Tablet
# 4  65 and above    Male     Unemployed  Several times a month      Laptop
#
#          reason    webplatform_types for_online_shopping for_reading_articles  \
# 0     Education  Government services                   4            1 (Never)
# 1          Work         News portals                   3                    2
# 2  Social Media  Government services                   4                    2
# 3  Social Media           E-commerce                   3                    2
# 4  Social Media    Educational sites                   2                    2
#
#   for_watching_videos  for_online_discussions social_media_integration  \
# 0           1 (Never)                       3                        2
# 1                   3                       4                        2
# 2                   3                       2                        2
# 3                   2                       5                        3
# 4                   2                       5                        2
#
#    overall_experience  will_recommend  accessiblity_for_disable  \
# 0                   4               4                         3
# 1                   3               4                         3
# 2                   4               4                         4
# 3                   1               4                         4
# 4                   4               3                         3
#
#    rating_for_finding_needs improvements additional_features
# 0                         2          NaN                 NaN
# 1                         3          NaN                 NaN
# 2                         1          NaN                 NaN
# 3                         5          NaN                 NaN
# 4                         2          NaN                 NaN

# %%
# Replacing column values in a pandas DataFrame
data.age.value_counts()
# Out:
# age
# 25 - 34         31
# 45 - 54         27
# 55 - 64         26
# 18 - 24         20
# Under 18        18
# 35 - 44         18
# 65 and above    11
# Name: count, dtype: int64

# %%
data['age'] = data['age'].map({'Under 18': '0-18', '18 - 24': '18-24','25 - 34':'25-34','35 - 44':'35-44',
                               '45 - 54':'45-54',
                               '55 - 64':'55-64',
                              '65 and above':'65-100'})

# %%
data.age.value_counts().sort_index()
# Out:
# age
# 0-18      18
# 18-24     20
# 25-34     31
# 35-44     18
# 45-54     27
# 55-64     26
# 65-100    11
# Name: count, dtype: int64

# %%
data['for_online_shopping'].value_counts()
# Out:
# for_online_shopping
# 4             42
# 2             38
# 3             36
# 1 (Never)     18
# 5 (Always)    17
# Name: count, dtype: int64

# %%
data['for_online_shopping'].map(type)
# Out:
# 0      <class 'int'>
# 1      <class 'int'>
# 2      <class 'int'>
# 3      <class 'int'>
# 4      <class 'int'>
#            ...
# 146    <class 'int'>
# 147    <class 'str'>
# 148    <class 'int'>
# 149    <class 'str'>
# 150    <class 'int'>
# Name: for_online_shopping, Length: 151, dtype: object

# %%
data['for_online_shopping'] = data['for_online_shopping'].map({'1 (Never)': 1, 2:2, 3:3, 4:4 , '5 (Always)':5})
data['for_reading_articles'] = data['for_reading_articles'].map({'1 (Never)': 1, 2:2, 3:3, 4:4 , '5 (Always)':5})
data['for_watching_videos'] = data['for_watching_videos'].map({'1 (Never)': 1, 2:2, 3:3, 4:4 , 5:5})
data['social_media_integration'] = data['social_media_integration'].map({'1 (Never)': 1, 2:2, 3:3, 4:4 , 5:5})

# %%
# Dealing With Missing Data
# Sorting Percentage Of Null Values In Each Column
(data.isnull().sum()/len(data)*100).sort_values(ascending = False)
# Out:
# improvements                25.827815
# additional_features         25.827815
# gender                       0.000000
# age                          0.000000
# occupation                   0.000000
# internet_usage               0.000000
# webplatform_types            0.000000
# for_online_shopping          0.000000
# device                       0.000000
# reason                       0.000000
# for_watching_videos          0.000000
# for_reading_articles         0.000000
# for_online_discussions       0.000000
# social_media_integration     0.000000
# will_recommend               0.000000
# overall_experience           0.000000
# rating_for_finding_needs     0.000000
# accessiblity_for_disable     0.000000
# dtype: float64

# %%
# As you can see we are getting lots of null values in additional_features and in improvements
# let's get rid of it
data['additional_features'].fillna(value='Not Specified',inplace=True)
data['improvements'].fillna(value='Not Specified',inplace=True)
data.isnull().sum()
# Out:
# age                         0
# gender                      0
# occupation                  0
# internet_usage              0
# device                      0
# reason                      0
# webplatform_types           0
# for_online_shopping         0
# for_reading_articles        0
# for_watching_videos         0
# for_online_discussions      0
# social_media_integration    0
# overall_experience          0
# will_recommend              0
# accessiblity_for_disable    0
# rating_for_finding_needs    0
# improvements                0
# additional_features         0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data preparation
age = data['age'].value_counts(ascending=True)

# Define color palette
colors = sns.color_palette("husl", len(age))

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))
ax = sns.barplot(x=age.index, y=age.values, order=age.index, palette=colors)

# Set labels and title
ax.set(xlabel='AGE', yticks=[], title='Responses based on age', frame_on=False)
ax.tick_params(length=0)

# Add percentage labels on all bars
total = age.sum()
for bar in ax.patches:   # Iterate over each bar
    height = bar.get_height()
    percentage = (height / total) * 100
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        height + 0.5,
        f'{percentage:.1f}%',
        ha='center',
        va='bottom',
        fontsize=10,
        color='black'
    )

plt.show()

# %%
# Responses based on gender
colors = ['#eca9f4', '#70d3fb']
data.groupby('gender').size().plot(kind='pie', colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Responses Based On Gender')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))
ax = sns.countplot(x='occupation', hue='gender', data=data, palette='husl')

# Set labels and title
plt.title("User's Occupation")
plt.xlabel("Occupation")
plt.ylabel("Count")

# Add percentage labels on all bars
total = len(data)
for bar in ax.patches:
    height = bar.get_height()
    if height > 0:  # Avoid division by zero
        percentage = (height / total) * 100
        ax.annotate(f'{percentage:.1f}%',
                    (bar.get_x() + bar.get_width() / 2, height + 0.5),
                    ha='center',
                    va='bottom',
                    fontsize=10,
                    color='black')

plt.show()

# %%
# How often user's use the internet
data['internet_usage'].value_counts()
# Out:
# internet_usage
# Several times a month    37
# Once a month             35
# Once a week              29
# Several times a week     19
# Rarely                   17
# Daily                    14
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting
fig, ax = plt.subplots(figsize=(12, 6))
ax = sns.countplot(x='internet_usage', data=data, palette='Set2')

# Set labels and title
plt.title("How often users use the internet")
plt.xlabel("Internet Usage")
plt.ylabel("Count")
plt.xticks(rotation=-45)

# Add percentage labels on all bars
total = len(data)
for bar in ax.patches:
    height = bar.get_height()
    if height > 0:  # Avoid division by zero
        percentage = (height / total) * 100
        ax.annotate(f'{percentage:.1f}%',
                    (bar.get_x() + bar.get_width() / 2, height + 0.5),
                    ha='center',
                    va='bottom',
                    fontsize=10,
                    color='black')

plt.show()

# %%
data['device'].value_counts()
# Out:
# device
# Laptop        61
# Tablet        43
# Desktop       27
# Smartphone    20
# Name: count, dtype: int64

# %%
# Devices used while using internet
colors = ['#8a6a8e', '#43b099','#d33e74','#be6017']
data.groupby('device').size().plot(kind='pie', colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Devices used while using internet')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set color palette
colors = sns.color_palette("Set2", 4)

# Create subplots
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

# Titles for the subplots
titles = ["For Online Shopping", "For Reading Articles", "For Watching Videos", "For Online Discussions"]
columns = ['for_online_shopping', 'for_reading_articles', 'for_watching_videos', 'for_online_discussions']

# Plotting
for i, ax in enumerate(axarr.flatten()):
    # Plotting the bar graph with custom colors
    counts = data[columns[i]].value_counts().sort_index()
    bars = ax.bar(counts.index, counts.values, color=colors[i])

    # Set title and labels
    ax.set_title(titles[i], fontsize=16)
    ax.set_xlabel("Response", fontsize=12)
    ax.set_ylabel("Count", fontsize=12)

    # Add percentage labels
    total = counts.sum()
    for bar in bars:
        height = bar.get_height()
        if height > 0:  # Avoid division by zero
            percentage = (height / total) * 100
            ax.annotate(f'{percentage:.1f}%',
                        (bar.get_x() + bar.get_width() / 2, height + 0.5),
                        ha='center', va='bottom',
                        fontsize=10, color='black')

# Adjust spacing
plt.subplots_adjust(hspace=0.5, wspace=0.4)
sns.despine()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the columns and titles for the subplots
columns = [
    'social_media_integration',
    'overall_experience',
    'will_recommend',
    'accessiblity_for_disable',
    'rating_for_finding_needs'
]

titles = [
    "Interaction with Social Media Integration",
    "Overall User Experience (1-5)",
    "Likelihood to Recommend (1-5)",
    "Accessibility for People with Disabilities (1-5)",
    "Success in Finding Needs (1-5)"
]

# Set color palette
colors = sns.color_palette("husl", len(columns))

# Create subplots
fig, axarr = plt.subplots(2, 3, figsize=(18, 10))
axarr = axarr.flatten()

# Plotting
for i, ax in enumerate(axarr[:len(columns)]):
    # Plot the bar graph with custom colors
    counts = data[columns[i]].value_counts().sort_index()
    bars = ax.bar(counts.index, counts.values, color=colors[i])

    # Set title and labels
    ax.set_title(titles[i], fontsize=16)
    ax.set_xlabel("Response", fontsize=12)
    ax.set_ylabel("Count", fontsize=12)

    # Add percentage labels
    total = counts.sum()
    for bar in bars:
        height = bar.get_height()
        if height > 0:  # Avoid division by zero
            percentage = (height / total) * 100
            ax.annotate(f'{percentage:.1f}%',
                        (bar.get_x() + bar.get_width() / 2, height + 0.5),
                        ha='center', va='bottom',
                        fontsize=10, color='black')

# Hide empty subplot if columns < 6
if len(columns) < 6:
    axarr[-1].axis('off')

# Adjust spacing
plt.subplots_adjust(hspace=0.5, wspace=0.4)
sns.despine()

plt.show()

# %%
#this is suggestion

data['age'] = data['age'].replace(['55-64', '65-100'], '55+')

# %%
#to handle the missing values
